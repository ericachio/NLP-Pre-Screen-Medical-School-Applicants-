# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from adjustText import adjust_text
import sklearn.metrics as metrics

# word2vec
import gensim
from gensim.models import Word2Vec
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer

# preprocess
import datetime
import statistics

# %%
# data = pd.read_csv("/gpfs/data/iime/data/admissions/adm_research_aptitude.csv")
# data = data.applymap(str)
# data.head(10)

# %%
# def cal_z_score(faculty_id, score, faculty_ID):
#     MEAN = faculty_ID.loc[faculty_ID['FACULTY_ID'] == faculty_id, 'MEAN'].iloc[0]
#     STANDARD_DEVIATION = faculty_ID.loc[faculty_ID['FACULTY_ID'] == faculty_id, 'STANDARD_DEVIATION'].iloc[0]
# #     print(type(score), type(MEAN), type(STANDARD_DEVIATION))
#     z = (score - MEAN) / STANDARD_DEVIATION
#     return z

# faculty_ID = data[['FACULTY_ID','APTITUDE_SCORE']]
# faculty_ID = faculty_ID.dropna()
# # faculty_ID = faculty_ID.groupby(['FACULTY_ID']).agg({'APTITUDE_SCORE':  {'Mean': np.mean, 'Standard Deviation': statistics.stdev}}).reset_index()
# faculty_ID['APTITUDE_SCORE'] = faculty_ID['APTITUDE_SCORE'].astype(float)
# faculty_ID = faculty_ID.groupby(['FACULTY_ID']).agg({'APTITUDE_SCORE': lambda col: col.tolist()}).reset_index()
# faculty_ID['MEAN'] = [np.mean(x) for x in faculty_ID.APTITUDE_SCORE]
# faculty_ID['STANDARD_DEVIATION'] = [statistics.stdev(x) for x in faculty_ID.APTITUDE_SCORE]
    
# # data = pd.to_numeric(data)
# data['Z_SCORE'] = data.apply(lambda row: cal_z_score(row['FACULTY_ID'], float(row['APTITUDE_SCORE']), faculty_ID), axis=1)

# %%
# df = pd.read_csv("old_data/processed_data.csv")
# df = df.drop('Unnamed: 0', axis=1)
# df.head()
data = pd.read_csv("data/adm_research_aptitude.csv")
data = data.applymap(str)
data.head()
# Out:
#    AMCAS_ID APP_YEAR                                    EXPERIENCE_NAME  \
# 0  10792888     2014  Independent Study and Research Assistant - Duk...
# 1  10792888     2014  Independent Study and Research Assistant - Duk...
# 2  10792888     2014  Independent Study and Research Assistant - Duk...
# 3  10792888     2014  Independent Study and Research Assistant - Duk...
# 4  10792888     2014  Independent Study and Research Assistant - Duk...
#
#                                     EXPERIENCE_DESCR  \
# 0  (Full-time paid position during the summers, 1...
# 1  (Full-time paid position during the summers, 1...
# 2  (Full-time paid position during the summers, 1...
# 3  (Full-time paid position during the summers, 1...
# 4  (Full-time paid position during the summers, 1...
#
#   MEANINGFUL_EXPERIENCE_DESCR  \
# 0                         nan
# 1                         nan
# 2                         nan
# 3                         nan
# 4                         nan
#
#                                    ORGANIZATION_NAME START_DATE  END_DATE  \
# 0  Duke Univ Hospital, Div of Infectious Diseases...   1-Jun-98  1-Jul-98
# 1  Duke Univ Hospital, Div of Infectious Diseases...   1-Jun-98  1-Jul-98
# 2  Duke Univ Hospital, Div of Infectious Diseases...   1-Aug-97  1-May-98
# 3  Duke Univ Hospital, Div of Infectious Diseases...   1-Aug-98  1-May-99
# 4  Duke Univ Hospital, Div of Infectious Diseases...   1-Jun-99  1-Jul-99
#
#   TOTAL_HOURS FACULTY_ID APTITUDE_SCORE APPLICATION_RANK
# 0       340.0     1839.0            1.0              3.0
# 1       340.0     1866.0            3.0              3.0
# 2       600.0     1839.0            1.0              3.0
# 3       600.0     1866.0            3.0              3.0
# 4       340.0     1839.0            1.0              3.0

# %%
from src import preprocess_research as preprocess_research

# faculty_ID = data[['FACULTY_ID','APTITUDE_SCORE']]
# faculty_ID = faculty_ID.dropna()
# faculty_ID['APTITUDE_SCORE'] = faculty_ID['APTITUDE_SCORE'].astype(float)
# faculty_ID = faculty_ID.groupby(['FACULTY_ID']).agg({'APTITUDE_SCORE': lambda col: col.tolist()}).reset_index()
# faculty_ID['MEAN'] = [np.mean(x) for x in faculty_ID.APTITUDE_SCORE]
# faculty_ID['STANDARD_DEVIATION'] = [statistics.stdev(x) for x in faculty_ID.APTITUDE_SCORE]
df = preprocess_research.graph_aptitude_z_score(data,'EXPERIENCE_DESCR')
df.head()
# faculty_ID
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/envs/researchThesis/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Z_SCORE'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/envs/researchThesis/lib/python3.7/site-packages/pandas/core/internals/managers.py in set(self, item, value)
#    1070         try:
# -> 1071             loc = self.items.get_loc(item)
#    1072         except KeyError:
#
# /opt/anaconda3/envs/researchThesis/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Z_SCORE'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-e5c8f57ff1ee> in <module>
#       7 # faculty_ID['MEAN'] = [np.mean(x) for x in faculty_ID.APTITUDE_SCORE]
#       8 # faculty_ID['STANDARD_DEVIATION'] = [statistics.stdev(x) for x in faculty_ID.APTITUDE_SCORE]
# ----> 9 df = preprocess_research.graph_aptitude_z_score(data,'EXPERIENCE_DESCR')
#      10 df.head()
#      11 # faculty_ID
#
# ~/Documents/sackler/thesis/src/preprocess_research.py in graph_aptitude_z_score(og_df, columnName, apt_score)
#     295     df = og_df.copy()
#     296     df = replace_newline(df)
# --> 297     df = z_score(df)
#     298     df = df.dropna()
#     299     print("finished processing, ", len(df), " rows")
#
# ~/Documents/sackler/thesis/src/preprocess_research.py in z_score(df)
#      59     faculty_ID['MEAN'] = [np.mean(x) for x in faculty_ID.APTITUDE_SCORE]
#      60     faculty_ID['STANDARD_DEVIATION'] = [statistics.stdev(x) for x in faculty_ID.APTITUDE_SCORE]
# ---> 61     df['Z_SCORE'] = df.apply(lambda row: cal_z_score(row['FACULTY_ID'], float(row['APTITUDE_SCORE']), faculty_ID), axis=1)
#      62
#      63
#
# /opt/anaconda3/envs/researchThesis/lib/python3.7/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    2936         else:
#    2937             # set column
# -> 2938             self._set_item(key, value)
#    2939
#    2940     def _setitem_slice(self, key, value):
#
# /opt/anaconda3/envs/researchThesis/lib/python3.7/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    2999         self._ensure_valid_index(value)
#    3000         value = self._sanitize_column(key, value)
# -> 3001         NDFrame._set_item(self, key, value)
#    3002
#    3003         # check if we are modifying a copy
#
# /opt/anaconda3/envs/researchThesis/lib/python3.7/site-packages/pandas/core/generic.py in _set_item(self, key, value)
#    3622
#    3623     def _set_item(self, key, value) -> None:
# -> 3624         self._data.set(key, value)
#    3625         self._clear_item_cache()
#    3626
#
# /opt/anaconda3/envs/researchThesis/lib/python3.7/site-packages/pandas/core/internals/managers.py in set(self, item, value)
#    1072         except KeyError:
#    1073             # This item wasn't present, just insert at end
# -> 1074             self.insert(len(self.items), item, value)
#    1075             return
#    1076
#
# /opt/anaconda3/envs/researchThesis/lib/python3.7/site-packages/pandas/core/internals/managers.py in insert(self, loc, item, value, allow_duplicates)
#    1179         new_axis = self.items.insert(loc, item)
#    1180
# -> 1181         block = make_block(values=value, ndim=self.ndim, placement=slice(loc, loc + 1))
#    1182
#    1183         for blkno, count in _fast_count_smallints(self._blknos[loc:]):
#
# /opt/anaconda3/envs/researchThesis/lib/python3.7/site-packages/pandas/core/internals/blocks.py in make_block(values, placement, klass, ndim, dtype)
#    3039         values = DatetimeArray._simple_new(values, dtype=dtype)
#    3040
# -> 3041     return klass(values, ndim=ndim, placement=placement)
#    3042
#    3043
#
# /opt/anaconda3/envs/researchThesis/lib/python3.7/site-packages/pandas/core/internals/blocks.py in __init__(self, values, placement, ndim)
#     123         if self._validate_ndim and self.ndim and len(self.mgr_locs) != len(self.values):
#     124             raise ValueError(
# --> 125                 f"Wrong number of items passed {len(self.values)}, "
#     126                 f"placement implies {len(self.mgr_locs)}"
#     127             )
#
# ValueError: Wrong number of items passed 90, placement implies 1

# %%
# df = data

# def cal_z_score(faculty_id, score, faculty_ID):
    
# #     MEAN = faculty_ID.loc[faculty_ID['FACULTY_ID'] == (faculty_id), 'MEAN'].iloc[0]
# #     STANDARD_DEVIATION = faculty_ID.loc[faculty_ID['FACULTY_ID'] == faculty_id, 'STANDARD_DEVIATION'].iloc[0]
#     MEAN = faculty_ID[faculty_ID['FACULTY_ID'] == faculty_id]['MEAN']
#     STANDARD_DEVIATION = faculty_ID[faculty_ID['FACULTY_ID'] == faculty_id]['STANDARD_DEVIATION']
#     z = (score - MEAN) / STANDARD_DEVIATION
#     return z

# faculty_ID = df[['FACULTY_ID','APTITUDE_SCORE']]
# faculty_ID = faculty_ID.dropna()
# faculty_ID['APTITUDE_SCORE'] = faculty_ID['APTITUDE_SCORE'].astype(float)
# faculty_ID = faculty_ID.groupby(['FACULTY_ID']).agg({'APTITUDE_SCORE': lambda col: col.tolist()}).reset_index()
# faculty_ID['MEAN'] = [np.mean(x) for x in faculty_ID.APTITUDE_SCORE]
# faculty_ID['STANDARD_DEVIATION'] = [statistics.stdev(x) for x in faculty_ID.APTITUDE_SCORE]
# df['Z_SCORE'] = df.apply(lambda row: cal_z_score(row['FACULTY_ID'], float(row['APTITUDE_SCORE']), (faculty_ID)), axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-42-1dc5bd9c121b> in <module>
#      16 faculty_ID['MEAN'] = [np.mean(x) for x in faculty_ID.APTITUDE_SCORE]
#      17 faculty_ID['STANDARD_DEVIATION'] = [statistics.stdev(x) for x in faculty_ID.APTITUDE_SCORE]
# ---> 18 df['Z_SCORE'] = df.apply(lambda row: cal_z_score(row['FACULTY_ID'], float(row['APTITUDE_SCORE']), (faculty_ID)), axis=1)
#
# /opt/anaconda3/envs/researchThesis/lib/python3.7/site-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    6876             kwds=kwds,
#    6877         )
# -> 6878         return op.get_result()
#    6879
#    6880     def applymap(self, func) -> "DataFrame":
#
# /opt/anaconda3/envs/researchThesis/lib/python3.7/site-packages/pandas/core/apply.py in get_result(self)
#     184             return self.apply_raw()
#     185
# --> 186         return self.apply_standard()
#     187
#     188     def apply_empty_result(self):
#
# /opt/anaconda3/envs/researchThesis/lib/python3.7/site-packages/pandas/core/apply.py in apply_standard(self)
#     311
#     312         # compute the result using the series generator
# --> 313         results, res_index = self.apply_series_generator()
#     314
#     315         # wrap results
#
# /opt/anaconda3/envs/researchThesis/lib/python3.7/site-packages/pandas/core/apply.py in apply_series_generator(self)
#     339         else:
#     340             for i, v in enumerate(series_gen):
# --> 341                 results[i] = self.f(v)
#     342                 keys.append(v.name)
#     343
#
# <ipython-input-42-1dc5bd9c121b> in <lambda>(row)
#      16 faculty_ID['MEAN'] = [np.mean(x) for x in faculty_ID.APTITUDE_SCORE]
#      17 faculty_ID['STANDARD_DEVIATION'] = [statistics.stdev(x) for x in faculty_ID.APTITUDE_SCORE]
# ---> 18 df['Z_SCORE'] = df.apply(lambda row: cal_z_score(row['FACULTY_ID'], float(row['APTITUDE_SCORE']), (faculty_ID)), axis=1)
#
# <ipython-input-42-1dc5bd9c121b> in cal_z_score(faculty_id, score, faculty_ID)
#       5 #     MEAN = faculty_ID.loc[faculty_ID['FACULTY_ID'] == (faculty_id), 'MEAN'].iloc[0]
#       6 #     STANDARD_DEVIATION = faculty_ID.loc[faculty_ID['FACULTY_ID'] == faculty_id, 'STANDARD_DEVIATION'].iloc[0]
# ----> 7     MEAN = faculty_ID[faculty_ID['FACULTY_ID'] == faculty_id]['MEAN']
#       8     STANDARD_DEVIATION = faculty_ID[faculty_ID['FACULTY_ID'] == faculty_id]['STANDARD_DEVIATION']
#       9     z = (score - MEAN) / STANDARD_DEVIATION
#
# /opt/anaconda3/envs/researchThesis/lib/python3.7/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      62         other = item_from_zerodim(other)
#      63
# ---> 64         return method(self, other)
#      65
#      66     return new_method
#
# /opt/anaconda3/envs/researchThesis/lib/python3.7/site-packages/pandas/core/ops/__init__.py in wrapper(self, other)
#     526         res_values = comparison_op(lvalues, rvalues, op)
#     527
# --> 528         return _construct_result(self, res_values, index=self.index, name=res_name)
#     529
#     530     wrapper.__name__ = op_name
#
# /opt/anaconda3/envs/researchThesis/lib/python3.7/site-packages/pandas/core/ops/__init__.py in _construct_result(left, result, index, name)
#     473     # We do not pass dtype to ensure that the Series constructor
#     474     #  does inference in the case where `result` has object-dtype.
# --> 475     out = left._constructor(result, index=index)
#     476     out = out.__finalize__(left)
#     477
#
# /opt/anaconda3/envs/researchThesis/lib/python3.7/site-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     305                 data = sanitize_array(data, index, dtype, copy, raise_cast_failure=True)
#     306
# --> 307                 data = SingleBlockManager(data, index, fastpath=True)
#     308
#     309         generic.NDFrame.__init__(self, data, fastpath=True)
#
# /opt/anaconda3/envs/researchThesis/lib/python3.7/site-packages/pandas/core/internals/managers.py in __init__(self, block, axis, do_integrity_check, fastpath)
#    1511
#    1512         if not isinstance(block, Block):
# -> 1513             block = make_block(block, placement=slice(0, len(axis)), ndim=1)
#    1514
#    1515         self.blocks = tuple([block])
#
# /opt/anaconda3/envs/researchThesis/lib/python3.7/site-packages/pandas/core/internals/blocks.py in make_block(values, placement, klass, ndim, dtype)
#    3032     if klass is None:
#    3033         dtype = dtype or values.dtype
# -> 3034         klass = get_block_type(values, dtype)
#    3035
#    3036     elif klass is DatetimeTZBlock and not is_datetime64tz_dtype(values):
#
# /opt/anaconda3/envs/researchThesis/lib/python3.7/site-packages/pandas/core/internals/blocks.py in get_block_type(values, dtype)
#    2989     vtype = dtype.type
#    2990
# -> 2991     if is_sparse(dtype):
#    2992         # Need this first(ish) so that Sparse[datetime] is sparse
#    2993         cls = ExtensionBlock
#
# /opt/anaconda3/envs/researchThesis/lib/python3.7/site-packages/pandas/core/dtypes/common.py in is_sparse(arr)
#     292     Returns `False` if the parameter has more than one dimension.
#     293     """
# --> 294     from pandas.core.arrays.sparse import SparseDtype
#     295
#     296     dtype = getattr(arr, "dtype", arr)
#
# /opt/anaconda3/envs/researchThesis/lib/python3.7/importlib/_bootstrap.py in _handle_fromlist(module, fromlist, import_, recursive)
#
# KeyboardInterrupt:

# %%
# faculty_ID.head()
# test = "1037.0"
# # MEAN = faculty_ID.loc[faculty_ID['FACULTY_ID'] == (faculty_id), 'MEAN'].iloc[0]
# # faculty_ID[faculty_ID['FACULTY_ID'] > 1.0]

# %%
# faculty_ID[faculty_ID['FACULTY_ID'] == test]['MEAN']
# Out:
# 0    3.013684
# Name: MEAN, dtype: float64

# %%
from src import word2vec

# %%
# untrained
word2vec.plot_embedding(df,'experience')

# %%
# pretrained
word2vec.plot_embedding(df,'experience', False)
